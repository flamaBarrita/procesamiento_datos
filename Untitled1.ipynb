# %%
url = "www.redhat.org"

result = url.startswith("www")

print(result)

print(url.endswith(".org"))

new_url = url.upper()

print("ORIGINAL", url, "RETURNED", new_url)
# Out:
# True
# True
# ORIGINAL www.redhat.org RETURNED WWW.REDHAT.ORG
