# %% [markdown]
# Ejercicio 1
#
# Escribe un programa que solicite ingresar una cadena de texto.
#
# El programa debe imprimir el texto original y, en una segunda línea de la salida, el número de caracteres ingresados.

# %%
String cadena
input(cadena)
print(cadena + ' ' + cadena.lenght)
